# %% [markdown]
# ### Read and process a single CSV file based on the desired headers

# %%
import csv
import os
from tabulate import tabulate

process_all = False  # Change to all to do every single graph :)

# Specify the default path to the CSV file for events when running
# single file
csv_file_path = r'EDF+\103918\103918.csv'

# Open the CSV file
def process_csvs(csv_file_path=csv_file_path):
    data = []
    with open(csv_file_path, 'r') as file:
        
        # Create a CSV DictReader object
        reader = csv.DictReader(file)
        
        # Iterate over the rows in the CSV file
        for row in reader:
            try:
                # Check if the stimulus column is not empty
                if row['stim']:
                    # Extract the required columns and append to data list
                    data.append([row['stim'], row['agree.response'], 
                        row['emotion']])
                    
            except KeyError as e:
                print(f"Column not found: {e}")

    # Print the data in a table format using tabulate
    print(tabulate(data, headers=['Stimulus', 'Response', 'Emotion'], 
        tablefmt='grid'))

            
def find_csvs():
    for root, dirs, files in os.walk(".", topdown=False):
        for name in files:
            if name.endswith('.csv'):
                print('Found', os.path.join(root, name))
                process_csvs(os.path.join(root, name))

if process_all:
    find_csvs() 
else: # We have chosen not to process all csvs, let's do only the default one
    process_csvs()
# Out:
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          5 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          4 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4     |          5 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4          |          5 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          5 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          5 | angry     |
# +---------------------------------------------+------------+-----------+

# %% [markdown]
# ### Do the same for every .csv

# %%
import csv
import os
from tabulate import tabulate

process_all = True # Change to all to do every single graph :)

# Specify the default path to the CSV file for events when running
# single file
csv_file_path = r'EDF+\103918\103918.csv'

# Open the CSV file
def process_csvs(csv_file_path=csv_file_path):
    data = []
    with open(csv_file_path, 'r') as file:
        
        # Create a CSV DictReader object
        reader = csv.DictReader(file)
        
        # Iterate over the rows in the CSV file
        for row in reader:
            try:
                # Check if the stimulus column is not empty
                if row['stim']:
                    # Extract the required columns and append to data list
                    data.append([row['stim'], row['agree.response'], 
                        row['emotion']])
                    
            except KeyError as e:
                print(f"Column not found: {e}")

    # Print the data in a table format using tabulate
    print(tabulate(data, headers=['Stimulus', 'Response', 'Emotion'], 
        tablefmt='grid'))

            
def find_csvs():
    for root, dirs, files in os.walk(".", topdown=False):
        for name in files:
            if name.endswith('.csv'):
                print('\nFound', os.path.join(root, name))
                process_csvs(os.path.join(root, name))

if process_all:
    find_csvs()
else: 
    process_csvs()
# Out:
# Found .\EDF+\103918\103918.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          5 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          4 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4     |          5 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4          |          5 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          5 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          5 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\145098\145098.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          5 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          4 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          5 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          4 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4        |          3 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          3 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4    |          4 | angry     |
# +-------------------------------------------+------------+-----------+
#
# Found .\EDF+\162636\162636.csv
# +------------------------------------------------+------------+-----------+
# | Stimulus                                       |   Response | Emotion   |
# +================================================+============+===========+
# | videos\1 excited\3 general\ratatChaseScene.mp4 |          4 | excited   |
# +------------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                      |          3 | happy     |
# +------------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4      |          4 | motivated |
# +------------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv            |          3 | relaxed   |
# +------------------------------------------------+------------+-----------+
# | videos\5 sad\3 general\ChampDeath.mp4          |          4 | sad       |
# +------------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4                  |          4 | horror    |
# +------------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4           |          4 | disgusted |
# +------------------------------------------------+------------+-----------+
# | videos\8 angry\2 general\thepiano.mp4          |          3 | angry     |
# +------------------------------------------------+------------+-----------+
#
# Found .\EDF+\192176\192176.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          4 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          4 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4     |          4 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4          |          4 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          4 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          5 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\222299\222299.csv
# +------------------------------------------------+------------+-----------+
# | Stimulus                                       |   Response | Emotion   |
# +================================================+============+===========+
# | videos\1 excited\3 general\ratatChaseScene.mp4 |          4 | excited   |
# +------------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                      |          4 | happy     |
# +------------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4      |          1 | motivated |
# +------------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv            |          3 | relaxed   |
# +------------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4             |          5 | sad       |
# +------------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4                  |          4 | horror    |
# +------------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4           |          4 | disgusted |
# +------------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4         |          5 | angry     |
# +------------------------------------------------+------------+-----------+
#
# Found .\EDF+\254362\254362.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          3 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          4 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv         |          3 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4          |          4 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          4 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          4 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\479015\479015.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          4 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          3 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv         |          4 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\3 general\ChampDeath.mp4       |          3 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          4 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\2 general\thepiano.mp4       |          3 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\541414\541414.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          4 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          5 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          2 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          5 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4        |          4 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          4 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4    |          4 | angry     |
# +-------------------------------------------+------------+-----------+
#
# Found .\EDF+\580357\580357.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          4 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          4 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          2 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          4 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\3 general\ChampDeath.mp4     |          3 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          3 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\2 general\thepiano.mp4     |          2 | angry     |
# +-------------------------------------------+------------+-----------+
#
# Found .\EDF+\598027\598027.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          3 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          4 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          2 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4     |          4 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\2 babies\sadBaby1.mp4          |          4 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          1 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          3 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\665252\665252.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          4 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          5 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          4 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          4 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4        |          5 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          4 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4    |          4 | angry     |
# +-------------------------------------------+------------+-----------+
#
# Found .\EDF+\687106\687106.csv
# +------------------------------------------------+------------+-----------+
# | Stimulus                                       |   Response | Emotion   |
# +================================================+============+===========+
# | videos\1 excited\3 general\ratatChaseScene.mp4 |          3 | excited   |
# +------------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                      |          4 | happy     |
# +------------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4      |          4 | motivated |
# +------------------------------------------------+------------+-----------+
# | videos\4 relaxed\1 meditation\meditation.mp4   |          4 | relaxed   |
# +------------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4             |          5 | sad       |
# +------------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4                  |          4 | horror    |
# +------------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4           |          5 | disgusted |
# +------------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4         |          5 | angry     |
# +------------------------------------------------+------------+-----------+
#
# Found .\EDF+\712563\712563.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          4 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          3 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv         |          4 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\3 general\ChampDeath.mp4       |          4 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          3 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          4 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\2 general\thepiano.mp4       |          3 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\750667\750667.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          3 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          4 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv         |          4 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4          |          4 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          4 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          4 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\778279\778279.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          5 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          4 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          4 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          5 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4        |          1 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          3 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4    |          5 | angry     |
# +-------------------------------------------+------------+-----------+
#
# Found .\EDF+\825255\825255.csv
# +---------------------------------------------+------------+-----------+
# | Stimulus                                    |   Response | Emotion   |
# +=============================================+============+===========+
# | videos\1 excited\1 motorsports\kenMiles.mp4 |          4 | excited   |
# +---------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                   |          2 | happy     |
# +---------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4   |          1 | motivated |
# +---------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4     |          5 | relaxed   |
# +---------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4          |          4 | sad       |
# +---------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4               |          4 | horror    |
# +---------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4        |          5 | disgusted |
# +---------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4      |          4 | angry     |
# +---------------------------------------------+------------+-----------+
#
# Found .\EDF+\859899\859899.csv
# +------------------------------------------------+------------+-----------+
# | Stimulus                                       |   Response | Emotion   |
# +================================================+============+===========+
# | videos\1 excited\3 general\ratatChaseScene.mp4 |          4 | excited   |
# +------------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                      |          4 | happy     |
# +------------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4      |          3 | motivated |
# +------------------------------------------------+------------+-----------+
# | videos\4 relaxed\1 meditation\meditation.mp4   |          4 | relaxed   |
# +------------------------------------------------+------------+-----------+
# | videos\5 sad\2 babies\sadBaby1.mp4             |          4 | sad       |
# +------------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4                  |          4 | horror    |
# +------------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4           |          5 | disgusted |
# +------------------------------------------------+------------+-----------+
# | videos\8 angry\2 general\thepiano.mp4          |          4 | angry     |
# +------------------------------------------------+------------+-----------+
#
# Found .\EDF+\901666\901666.csv
# +------------------------------------------------+------------+-----------+
# | Stimulus                                       |   Response | Emotion   |
# +================================================+============+===========+
# | videos\1 excited\3 general\ratatChaseScene.mp4 |          4 | excited   |
# +------------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                      |          3 | happy     |
# +------------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4      |          1 | motivated |
# +------------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4        |          5 | relaxed   |
# +------------------------------------------------+------------+-----------+
# | videos\5 sad\3 general\ChampDeath.mp4          |          4 | sad       |
# +------------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4                  |          4 | horror    |
# +------------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4           |          5 | disgusted |
# +------------------------------------------------+------------+-----------+
# | videos\8 angry\2 general\thepiano.mp4          |          5 | angry     |
# +------------------------------------------------+------------+-----------+
#
# Found .\EDF+\919513\919513.csv
# +------------------------------------------------+------------+-----------+
# | Stimulus                                       |   Response | Emotion   |
# +================================================+============+===========+
# | videos\1 excited\3 general\ratatChaseScene.mp4 |          5 | excited   |
# +------------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                      |          4 | happy     |
# +------------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4      |          2 | motivated |
# +------------------------------------------------+------------+-----------+
# | videos\4 relaxed\3 general\asmr.mkv            |          3 | relaxed   |
# +------------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4             |          5 | sad       |
# +------------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4                  |          1 | horror    |
# +------------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4           |          5 | disgusted |
# +------------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4         |          5 | angry     |
# +------------------------------------------------+------------+-----------+
#
# Found .\EDF+\946416\946416.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          5 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          4 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          4 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          5 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4        |          5 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          4 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4    |          5 | angry     |
# +-------------------------------------------+------------+-----------+
#
# Found .\EDF+\Zacker\Zacker.csv
# +-------------------------------------------+------------+-----------+
# | Stimulus                                  |   Response | Emotion   |
# +===========================================+============+===========+
# | videos\1 excited\2 sports\NBA.mp4         |          4 | excited   |
# +-------------------------------------------+------------+-----------+
# | videos\2 happy\scooby.mp4                 |          5 | happy     |
# +-------------------------------------------+------------+-----------+
# | videos\3 motivated\motivationalAuthor.mp4 |          3 | motivated |
# +-------------------------------------------+------------+-----------+
# | videos\4 relaxed\2 nature\waterfall.mp4   |          5 | relaxed   |
# +-------------------------------------------+------------+-----------+
# | videos\5 sad\1 animals\saddogs.mp4        |          4 | sad       |
# +-------------------------------------------+------------+-----------+
# | videos\6 horror\conjuring.mp4             |          5 | horror    |
# +-------------------------------------------+------------+-----------+
# | videos\7 disgusted\trainspotting.mp4      |          5 | disgusted |
# +-------------------------------------------+------------+-----------+
# | videos\8 angry\1 animals\angrydogs.mp4    |          4 | angry     |
# +-------------------------------------------+------------+-----------+

# %% [markdown]
# ### Data Manipulation Options:
#
# - Rename EDF files to incorporate rating information for processing.
# - Segregate EEG segments based on ratings for analysis filtering.
#
# In essence, we can either:
# - Include rating information in the analysis.
# - Filter files for analysis based on ratings.
